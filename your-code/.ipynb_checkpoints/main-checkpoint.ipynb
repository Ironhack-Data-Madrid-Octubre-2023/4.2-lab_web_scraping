# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
html = req.get(url).text
html
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"  data-a11y-animated-images="system" data-a11y-link-underlines="true">\n\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-b92e9647318f.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-5d486a4ede8e.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous"
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
soup = bs(html, 'html.parser')

# %%
soup.find_all('article')
# Out:
# [<article class="Box-row d-flex" id="pa-Jonghakseo">
#  <a class="Link color-fg-muted f6" data-view-component="true" href="#pa-Jonghakseo" style="width: 16px;" text="center">
#      1
#  </a>
#  <div class="mx-3">
#  <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":53500778,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="7ae74a609266457066efb1f8996583ac216d5b2eccbda0e04aca9fcc152f6c87" data-view-component="true" href="/Jonghakseo">
#  <img alt="@Jonghakseo" class="rounded avatar-user" height="48" src="https://avatars.githubusercontent.com/u/53500778?s=96&amp;v=4" width="48"/>
#  </a> </div>
#  <div class="d-sm-flex flex-auto">
#  <div class="col-sm-8 d-md-flex">
#  <div class="col-md-6">
#  <h1 class="h3 lh-condensed">
# ...

# %%
soup.find('h1')
# Out:
# <h1 class="sr-only" id="search-suggestions-dialog-header">Search code, repositories, users, issues, pull requests...</h1>

# %%
tablas=soup.find_all('h1', class_="h3 lh-condensed")
tablas
# Out:
# [<h1 class="h3 lh-condensed">
#  <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":53500778,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="7ae74a609266457066efb1f8996583ac216d5b2eccbda0e04aca9fcc152f6c87" data-view-component="true" href="/Jonghakseo">
#              JongHak Seo
#  </a> </h1>,
#  <h1 class="h3 lh-condensed">
#  <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":27340033,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="99d96df5ce919220703f57dcc480f5570dfdad36f8f00832dbd71b0799036af0" data-view-component="true" href="/casper-hansen">
# ...

# %%
nombres = []

for elemento in soup.find_all('h1', class_="h3 lh-condensed"):
    nombre = elemento.text.strip()
    nombres.append(nombre)

print(nombres)
# Out:
# ['JongHak Seo', 'Casper', 'J. Nick Koston', 'Yudong Jin', 'Tim Neutkens', 'Laurent Mazare', 'oobabooga', 'Henrik Rydgård', 'Stan Girard', 'Vaxry', 'Nikita Sobolev', 'Michael Lynch', 'Junior Garcia', 'dkhamsing', 'Vaibhav Srivastav', 'Martin von Zweigbergk', 'Stephen Celis', 'Georgios Konstantopoulos', 'Ben V. Brown', 'Guilherme Branco Stracini', "John O'Reilly", 'Adrienne Walker', 'Ivan Starkov', 'DavHau', 'Andreas Thomas']

# %%
alias=soup.find_all('p', class_="f4 text-normal mb-1")[0].text.strip()
alias
# Out:
# 'Jonghakseo'

# %%
alias=[]
for e in soup.find_all('p', class_="f4 text-normal mb-1"):
    alia = e.text.strip()
    alias.append(alia)
print(alias)
# Out:
# ['Jonghakseo', 'casper-hansen', 'bdraco', 'krahets', 'timneutkens', 'LaurentMazare', 'hrydgard', 'StanGirard', 'vaxerski', 'sobolevn', 'mtlynch', 'jrgarciadev', 'Vaibhavs10', 'martinvonz', 'stephencelis', 'gakonst', 'Ralim', 'guibranco', 'joreilly', 'quisquous', 'istarkov', 'chronark']

# %%
tarjetas = soup.find_all('div', class_="col-md-6")
data = []

for tarjeta in tarjetas:
    try:
        nombre = tarjeta.find('h1', class_="h3 lh-condensed").text.strip()
        alias_element = tarjeta.find('p', class_="f4 text-normal mb-1")
        if alias_element:
            alias = alias_element.text.strip()
        else:
            alias = ''
        data.append({'nombre': nombre, 'alias': alias})
    except:
        continue

print(data)
# Out:
# [{'nombre': 'JongHak Seo', 'alias': 'Jonghakseo'}, {'nombre': 'Casper', 'alias': 'casper-hansen'}, {'nombre': 'J. Nick Koston', 'alias': 'bdraco'}, {'nombre': 'Yudong Jin', 'alias': 'krahets'}, {'nombre': 'Tim Neutkens', 'alias': 'timneutkens'}, {'nombre': 'Laurent Mazare', 'alias': 'LaurentMazare'}, {'nombre': 'oobabooga', 'alias': ''}, {'nombre': 'Henrik Rydgård', 'alias': 'hrydgard'}, {'nombre': 'Stan Girard', 'alias': 'StanGirard'}, {'nombre': 'Vaxry', 'alias': 'vaxerski'}, {'nombre': 'Nikita Sobolev', 'alias': 'sobolevn'}, {'nombre': 'Michael Lynch', 'alias': 'mtlynch'}, {'nombre': 'Junior Garcia', 'alias': 'jrgarciadev'}, {'nombre': 'dkhamsing', 'alias': ''}, {'nombre': 'Vaibhav Srivastav', 'alias': 'Vaibhavs10'}, {'nombre': 'Martin von Zweigbergk', 'alias': 'martinvonz'}, {'nombre': 'Stephen Celis', 'alias': 'stephencelis'}, {'nombre': 'Georgios Konstantopoulos', 'alias': 'gakonst'}, {'nombre': 'Ben V. Brown', 'alias': 'Ralim'}, {'nombre': 'Guilherme Branco Stracini', 'alias':
# ...

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
html = req.get(url).text

# %%
soup = bs(html, 'html.parser')

# %%
soup.find_all('article')
# Out:
# [<article class="Box-row">
#  <div class="float-right d-flex">
#  <div class="BtnGroup d-flex" data-view-component="true">
#  <a aria-label="You must be signed in to star a repository" class="tooltipped tooltipped-s btn-sm btn BtnGroup-item" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"star button","repository_id":707551301,"auth_type":"LOG_IN","originating_url":"https://github.com/trending/python?since=daily","user_id":null}}' data-hydro-click-hmac="4f8c7bad160bced35b32174e6d9b8cd726f76ee5b472334539330fbc80ab371b" data-view-component="true" href="/login?return_to=%2Fdeepseek-ai%2FDeepSeek-Coder" rel="nofollow"> <svg aria-hidden="true" class="octicon octicon-star v-align-text-bottom d-none d-md-inline-block mr-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# ...

# %%
alias=[]
for e in soup.find_all('h2', class_="h3 lh-condensed"):
    alia = e.text.strip()
    alias.append(alia)
print(alias)

#hay que limpiarlo jeje
# Out:
# ['deepseek-ai /\n\n      DeepSeek-Coder', 'jianchang512 /\n\n      pyvideotrans', 'yt-dlp /\n\n      yt-dlp', 'google /\n\n      jax', 'dreamgaussian /\n\n      dreamgaussian', 'AUTOMATIC1111 /\n\n      stable-diffusion-webui', 'microsoft /\n\n      DeepSpeed', 'blakeblackshear /\n\n      frigate', 'kovidgoyal /\n\n      calibre', 'graphdeco-inria /\n\n      gaussian-splatting', 'LorenEteval /\n\n      Furious', 'Pythagora-io /\n\n      gpt-pilot', 'jxnl /\n\n      instructor', 'imoneoi /\n\n      openchat', 'MorvanZhou /\n\n      Reinforcement-learning-with-tensorflow', 'yihong0618 /\n\n      tg_bing_dalle', 'home-assistant /\n\n      core', 'microsoft /\n\n      DeepSpeed-MII', 'aladdinpersson /\n\n      Machine-Learning-Collection', 'kivy /\n\n      python-for-android', 'microsoft /\n\n      CodeT', '521xueweihan /\n\n      HelloGitHub', 'reactive-python /\n\n      reactpy', 'oobabooga /\n\n      text-generation-webui', 'drivendata /\n\n      cookiecutter-data-science']

# %%
repositories = []

for e in soup.find_all('h2', class_="h3 lh-condensed"):
    rep = e.text.strip()
    cleaned_rep = ' '.join(rep.split())
    repositories.append(cleaned_rep)

print(repositories)
# Out:
# ['deepseek-ai / DeepSeek-Coder', 'jianchang512 / pyvideotrans', 'yt-dlp / yt-dlp', 'google / jax', 'dreamgaussian / dreamgaussian', 'AUTOMATIC1111 / stable-diffusion-webui', 'microsoft / DeepSpeed', 'blakeblackshear / frigate', 'kovidgoyal / calibre', 'graphdeco-inria / gaussian-splatting', 'LorenEteval / Furious', 'Pythagora-io / gpt-pilot', 'jxnl / instructor', 'imoneoi / openchat', 'MorvanZhou / Reinforcement-learning-with-tensorflow', 'yihong0618 / tg_bing_dalle', 'home-assistant / core', 'microsoft / DeepSpeed-MII', 'aladdinpersson / Machine-Learning-Collection', 'kivy / python-for-android', 'microsoft / CodeT', '521xueweihan / HelloGitHub', 'reactive-python / reactpy', 'oobabooga / text-generation-webui', 'drivendata / cookiecutter-data-science']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
html = req.get(url).text
soup = bs(html, 'html.parser')
images=soup.find_all('img')
images
# Out:
# [<img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>,
#  <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>,
#  <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>,
#  <img alt="Featured article" class="mw-file-element" data-file-height="443" data-file-width="466" decoding="async" height="19" src="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/30px-Cscr-featured.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/40px-Cscr-featured.svg.png 2x" width="20"/>,
# ...

# %%
for image in images:
    image_link = image.get('src')
    if image_link:
            print(image_link)
# Out:
# /static/images/icons/wikipedia.png
# /static/images/mobile/copyright/wikipedia-wordmark-en.svg
# /static/images/mobile/copyright/wikipedia-tagline-en.svg
# //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG
# //upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg/220px-Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
html = req.get(url).text
soup = bs(html, 'html.parser')
links=soup.find_all('a')

# %%
list_of_links = []
for link in links:
    href = link.get('href')
    list_of_links.append(href)

# %%
filtered_links = []
for link in list_of_links:
    # Verificar si el enlace no es nulo (None) y si comienza con "http"
    if link and link.startswith("http"):
        # Si ambas condiciones se cumplen, agregar el enlace a la lista 'filtered_links'
        filtered_links.append(link)
filtered_links
# Out:
# ['https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  'https://af.wikipedia.org/wiki/Python',
#  'https://als.wikipedia.org/wiki/Python',
#  'https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86_(%D8%AA%D9%88%D8%B6%D9%8A%D8%AD)',
#  'https://az.wikipedia.org/wiki/Python_(d%C9%99qiql%C9%99%C5%9Fdirm%C9%99)',
#  'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)',
#  'https://be.wikipedia.org/wiki/Python',
#  'https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%BF%D0%BE%D1%8F%D1%81%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5)',
#  'https://cs.wikipedia.org/wiki/Python_(rozcestn%C3%ADk)',
#  'https://da.wikipedia.org/wiki/Python',
#  'https://de.wikipedia.org/wiki/Python',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
html = req.get(url).text
soup = bs(html, 'html.parser')
changed_titles_element = soup.find('div', class_='uscitem')

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#NO FUNCIONA

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#NO FUNCIONA

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#NO FUNCIONA

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#NO FUNCIONA

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#NO FUNCIONA

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
html = req.get(url).text
soup = bs(html, 'html.parser')

total_info = soup.find_all('a', class_ = 'link-box')

total = []
for i in total_info:
    languages = i.find('strong').text.strip()
    articles = i.find('small').text.strip()
    articles = articles.replace('\xa0', '')
    total.append((languages, articles))
    
print(total)
# Out:
# [('English', '6740000+ articles'), ('Ð\xa0Ñ\x83Ñ\x81Ñ\x81ÐºÐ¸Ð¹', '1946000+ Ñ\x81Ñ\x82Ð°Ñ\x82ÐµÐ¹'), ('EspaÃ±ol', '1904000+ artÃ\xadculos'), ('æ\x97¥æ\x9c¬èª\x9e', '1392000+ è¨\x98äº\x8b'), ('Deutsch', '2850000+ Artikel'), ('FranÃ§ais', '2566000+ articles'), ('Italiano', '1834000+ voci'), ('Ø§Ù\x84Ø¹Ø±Ø¨Ù\x8aØ©', '1221000+ Ù\x85Ù\x82Ø§Ù\x84Ø©'), ('PortuguÃªs', '1112000+ artigos'), ('Ù\x81Ø§Ø±Ø³Û\x8c', '980000+ Ù\x85Ù\x82Ø§Ù\x84Ù\x87')]

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
url = 'https://data.gov.uk/'

html = req.get(url).text
soup = bs(html, 'html.parser')

data = soup.find('ul', class_ = 'govuk-list dgu-topics__list').text.split('\n')
data
# Out:
# ['',
#  '',
#  'Business and economy',
#  'Small businesses, industry, imports, exports and trade',
#  '',
#  '',
#  'Crime and justice',
#  'Courts, police, prison, offenders, borders and immigration',
#  '',
#  '',
#  'Defence',
#  'Armed forces, health and safety, search and rescue',
#  '',
#  '',
#  'Education',
#  'Students, training, qualifications and the National Curriculum',
#  '',
#  '',
#  'Environment',
#  'Weather, flooding, rivers, air quality, geology and agriculture',
#  '',
#  '',
#  'Government',
#  'Staff numbers and pay, local councillors and department business plans',
#  '',
#  '',
#  'Government spending',
#  'Includes all payments by government departments over £25,000',
#  '',
#  '',
#  'Health',
#  'Includes smoking, drugs, alcohol, medicine performance and hospitals',
#  '',
#  '',
#  'Mapping',
#  'Addresses, boundaries, land ownership, aerial photographs, seabed and land terrain',
#  '',
#  '',
#  'Society',
# ...

# %%
new_data = [i for i in data if i != '']
grupo = {}

for i in range(0, len(new_data), 2):
    key = new_data[i]
    value = new_data[i + 1]
    grupo[key] = value
grupo
# Out:
# {'Business and economy': 'Small businesses, industry, imports, exports and trade',
#  'Crime and justice': 'Courts, police, prison, offenders, borders and immigration',
#  'Defence': 'Armed forces, health and safety, search and rescue',
#  'Education': 'Students, training, qualifications and the National Curriculum',
#  'Environment': 'Weather, flooding, rivers, air quality, geology and agriculture',
#  'Government': 'Staff numbers and pay, local councillors and department business plans',
#  'Government spending': 'Includes all payments by government departments over £25,000',
#  'Health': 'Includes smoking, drugs, alcohol, medicine performance and hospitals',
#  'Mapping': 'Addresses, boundaries, land ownership, aerial photographs, seabed and land terrain',
#  'Society': 'Employment, benefits, household finances, poverty and population',
#  'Towns and cities': 'Includes housing, urban planning, leisure, waste and energy, consumption',
# ...

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
html = req.get(url).text
soup = bs(html, 'html.parser')

# %%
tabla = soup.find_all('tr')
lang = []
for fila in tabla:
    lang.append(fila.text.split('\n'))
    
lang = pd.DataFrame(lang)[:10]
lang
# Out:
#   0                                                  1  2   \
# 0                                              Language
# 1     Mandarin Chinese(incl. Standard Chinese, but e...
# 2                                               Spanish
# 3                                               English
# 4                Hindi(excl. Urdu, and other languages)
# 5                                            Portuguese
# 6                                               Bengali
# 7                                               Russian
# 8                                              Japanese
# 9                          Yue Chinese(incl. Cantonese)
#
#                           3  4                5  6             7  8     9   \
# 0  Native speakers(millions)     Language family           Branch     None
# 1                        939        Sino-Tibetan          Sinitic     None
# 2                        485       Indo-European          Romance     None
# ...

# %%
lang = lang.iloc[:, 1:4]
lang
# Out:
#                                                    1 2  \
# 0                                           Language
# 1  Mandarin Chinese(incl. Standard Chinese, but e...
# 2                                            Spanish
# 3                                            English
# 4             Hindi(excl. Urdu, and other languages)
# 5                                         Portuguese
# 6                                            Bengali
# 7                                            Russian
# 8                                           Japanese
# 9                       Yue Chinese(incl. Cantonese)
#
#                            3
# 0  Native speakers(millions)
# 1                        939
# 2                        485
# 3                        380
# 4                        345
# 5                        236
# 6                        234
# 7                        147
# 8                        123
# 9                       86.1

# %%
lang = lang.drop(2, axis= 1)
lang = lang.drop(0, axis= 0)
lang.columns = ['Language', 'Native Speakers (millions)']
lang
# Out:
#                                             Language  \
# 1  Mandarin Chinese(incl. Standard Chinese, but e...
# 2                                            Spanish
# 3                                            English
# 4             Hindi(excl. Urdu, and other languages)
# 5                                         Portuguese
# 6                                            Bengali
# 7                                            Russian
# 8                                           Japanese
# 9                       Yue Chinese(incl. Cantonese)
#
#   Native Speakers (millions)
# 1                        939
# 2                        485
# 3                        380
# 4                        345
# 5                        236
# 6                        234
# 7                        147
# 8                        123
# 9                       86.1

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
