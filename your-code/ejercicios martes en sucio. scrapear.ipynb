# %%
#%pip install beautifulsoup4

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
html = req.get(url).content   

html

# %%
soup = bs(html, 'html.parser')

type(soup)

# %%
soup

# %%
x = soup.find_all("div")
len(x)

# %%
#div_element = soup.find('div')

#div_element

# %%
div_element = soup.find('div', class_="Box").find_all('article', class_="Box-row d-flex")

len(div_element)

# %%
#div_element = soup.find('div', class_="Box").find('article', class_="Box-row d-flex")

#len(div_element)

#n = div_element.find('h1', class_="h3 lh-condensed").text

#alias = div_element.find('p', class_= 'f4 text-normal mb-1').text

# %%
ejer = []

for dev in div_element:
    
    try:   
        name = dev.find('h1', class_="h3 lh-condensed").text.strip()
        alias = dev.find('p', class_= 'f4 text-normal mb-1').text.strip()    
        ejer.append( name +' ' +'(' + alias + ')')
        
    except:
        ejer.append(name)
        
ejer

# %%
#### Display the trending Python repositories in GitHub

#The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# This is the url you will scrape in this exercise
url_2 = 'https://github.com/trending/python?since=daily'

# %%
html_2 = req.get(url_2).content

html_2

# %%
sopa = bs(html_2, 'html.parser')

sopa

# %%
x2 = sopa.find_all('div')

len(x2)

# %%
div_element2 = sopa.find('div', class_ ='Box').find('article', class_="Box-row")

div_element2

# %%
len(div_element2)

# %%
trending=div_element2.find('h2', class_="h3 lh-condensed").text.strip()

trending

# %%
div_element2_all = sopa.find('div', class_ ='Box').find_all('article', class_="Box-row")

div_element2

# %%
ejer_2 = []

for dev in div_element2_all:
    try:
        trending=dev.find('h2', class_="h3 lh-condensed").text.strip()
        
        ejer_2.append(trending)
        
    except:
        ejer_2.append(trending)
        
ejer_2

# %%
type(ejer_2)

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url_3= 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
html_3 = req.get(url_3).content

html_3

# %%
miso = bs (html_3, 'html.parser')

miso

# %%
pics = miso.find('div', {'id':'bodyContent'})

pics

# %%
pics.find_all('img')

# %%
#para poder inspecionar mejor.

miso_tofu = pics.find_all('img')

# %%
ejer_3 =[]

for image in miso_tofu:
    print (image['src'])
    
ejer_3.append(miso_tofu)

ejer_3

# %%
#miso_tofu['src']

# %%
url_4='https://en.wikipedia.org/wiki/Python'

# %%
html_4 = req.get(url_4).content

html_4

# %%
snake_soup = bs(html_4, 'html.parser')

snake_soup

# %%
x4= snake_soup.find_all('div')

len(x4)

# %%
div_element3 = snake_soup.find('div', class_="mw-parser-output")

div_element3

# %%
len(div_element3)

# %%
body = snake_soup.find('div', class_="mw-parser-output").find_all('li')

body

# %%
list_of_links = []

for link in body:
    list_of_links.append(f'wwww.wikipedia.org{link.find("a")["href"]}')
    #list.append(lo que quierrs meter)
list_of_links

# %%
url_5 = 'http://uscode.house.gov/download/download.shtml'

# %%
html_5 = req.get(url_5).content

html_5

# %%
bold_eag = bs(html_5, 'html.parser')

bold_eag

# %%
x5 = bold_eag.find_all('div')

x5

# %%
div_element5 = bold_eag.find_all('div', class_='usctitlechanged')


div_element5

# %%
df_2 = pd.read_clipboard()  #control c y contrl v para copiar las tablas

df_2

# %%
df_2 = pd.read_clipboard(sep='\t')


df_2

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url_wiki= 'https://www.wikipedia.org/'

html_6 = req.get(url_wiki).content

# %%
html_6 = req.get(url_wiki).content   

html_6
# Out:
# b'<!DOCTYPE html>\n<html lang="en" class="no-js">\n<head>\n<meta charset="utf-8">\n<title>Wikipedia</title>\n<meta name="description" content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation.">\n<script>\ndocument.documentElement.className = document.documentElement.className.replace( /(^|\\s)no-js(\\s|$)/, "$1js-enabled$2" );\n</script>\n<meta name="viewport" content="initial-scale=1,user-scalable=yes">\n<link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png">\n<link rel="shortcut icon" href="/static/favicon/wikipedia.ico">\n<link rel="license" href="//creativecommons.org/licenses/by-sa/4.0/">\n<style>\n.sprite{background-image:linear-gradient(transparent,transparent),url(portal/wikipedia.org/assets/img/sprite-8bb90067.svg);background-repeat:no-repeat;display:inline-block;vertical-align:middle}.svg-Commons-logo_sister{background-position:0 0;width:47px;height:47px}.svg-MediaWiki-logo_sist
# ...

# %%
soup_idiomas = bs(html_6, 'html.parser')

soup_idiomas
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia</title>
# <meta content="Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation." name="description"/>
# <script>
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)no-js(\s|$)/, "$1js-enabled$2" );
# </script>
# <meta content="initial-scale=1,user-scalable=yes" name="viewport"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="//creativecommons.org/licenses/by-sa/4.0/" rel="license"/>
# <style>
# ...

# %%
x6 = soup_idiomas.find('div', {'class':'central-featured'})

x6
# Out:
# <div class="central-featured" data-el-section="primary links">
# <!-- #1. en.wikipedia.org - 1 719 062 000 views/day -->
# <div class="central-featured-lang lang1" dir="ltr" lang="en">
# <a class="link-box" data-slogan="The Free Encyclopedia" href="//en.wikipedia.org/" id="js-link-box-en" title="English — Wikipedia — The Free Encyclopedia">
# <strong>English</strong>
# <small><bdi dir="ltr">6 715 000+</bdi> <span>articles</span></small>
# </a>
# </div>
# <!-- #2. ja.wikipedia.org - 211 317 000 views/day -->
# <div class="central-featured-lang lang2" dir="ltr" lang="ja">
# <a class="link-box" data-slogan="フリー百科事典" href="//ja.wikipedia.org/" id="js-link-box-ja" title="Nihongo — ウィキペディア — フリー百科事典">
# <strong>日本語</strong>
# <small><bdi dir="ltr">1 387 000+</bdi> <span>記事</span></small>
# </a>
# </div>
# <!-- #3. es.wikipedia.org - 198 289 000 views/day -->
# <div class="central-featured-lang lang3" dir="ltr" lang="es">
# ...

# %%
idiomas = x6.find_all('strong')

idiomas
# Out:
# [<strong>English</strong>,
#  <strong>日本語</strong>,
#  <strong>Español</strong>,
#  <strong>Русский</strong>,
#  <strong>Deutsch</strong>,
#  <strong>Français</strong>,
#  <strong>Italiano</strong>,
#  <strong>中文</strong>,
#  <strong>Português</strong>,
#  <strong><bdi dir="rtl">العربية</bdi></strong>]

# %%
numeros = x6.find_all('small')

numeros
# Out:
# [<small><bdi dir="ltr">6 715 000+</bdi> <span>articles</span></small>,
#  <small><bdi dir="ltr">1 387 000+</bdi> <span>記事</span></small>,
#  <small><bdi dir="ltr">1 892 000+</bdi> <span>artículos</span></small>,
#  <small><bdi dir="ltr">1 938 000+</bdi> <span>статей</span></small>,
#  <small><bdi dir="ltr">2 836 000+</bdi> <span>Artikel</span></small>,
#  <small><bdi dir="ltr">2 553 000+</bdi> <span>articles</span></small>,
#  <small><bdi dir="ltr">1 826 000+</bdi> <span>voci</span></small>,
#  <small><bdi dir="ltr">1 377 000+</bdi> <span class="jscnconv" data-hans="条目" data-hant="條目">条目 / 條目</span></small>,
#  <small><bdi dir="ltr">1 109 000+</bdi> <span>artigos</span></small>,
#  <small><bdi dir="ltr">1 217 000+</bdi> <span>مقالة</span></small>]

# %%
numeros = [e.text.replace('\xa0', '').split('+')[0] for e in numeros]

# %%
dict(zip(idiomas, numeros))
# Out:
# {<strong>English</strong>: '6715000',
#  <strong>日本語</strong>: '1387000',
#  <strong>Español</strong>: '1892000',
#  <strong>Русский</strong>: '1938000',
#  <strong>Deutsch</strong>: '2836000',
#  <strong>Français</strong>: '2553000',
#  <strong>Italiano</strong>: '1826000',
#  <strong>中文</strong>: '1377000',
#  <strong>Português</strong>: '1109000',
#  <strong><bdi dir="rtl">العربية</bdi></strong>: '1217000'}

# %%
# This is the url you will scrape in this exercise
url_uk = 'https://data.gov.uk/'

# %%
html_uk = req.get(url_uk).text

sopa = bs(html_uk, 'html.parser')

# %%
uk_tags = sopa.find('div', class_= 'govuk-grid-column-full').find_all('h3', class_='govuk-heading-s dgu-topics__heading')

uk_tags

# %%
ejer_5 = []

for c in uk_tags:
    tren=c.text.strip()
    ejer_5.append(tren)

ejer_5

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe
# # This is the url you will scrape in this exercise
# url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
url_wiki_tabla= 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
html_8 = req.get(url_wiki_tabla).content   

html_8
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of languages by number of native speakers - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-dis
# ...

# %%
sopa_wiki_tabla = bs(html_8, 'html.parser')

# %%
tabla_idiomas = sopa_wiki_tabla.find('tbody')

tabla_idiomas
# Out:
# <tbody><tr>
# <th>Language
# </th>
# <th data-sort-type="number">Native speakers<br/><small>(millions)</small>
# </th>
# <th>Language family
# </th>
# <th>Branch
# </th></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_639:cmn" title="ISO 639:cmn">Mandarin Chinese</a><br/>(incl. <a href="/wiki/Standard_Chinese" title="Standard Chinese">Standard Chinese</a>, but excl. <a href="/wiki/Varieties_of_Chinese" title="Varieties of Chinese">other varieties</a>)
# </td>
# <td>939
# </td>
# <td><a href="/wiki/Sino-Tibetan_languages" title="Sino-Tibetan languages">Sino-Tibetan</a>
# </td>
# <td><a href="/wiki/Sinitic_languages" title="Sinitic languages">Sinitic</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/ISO_639:spa" title="ISO 639:spa">Spanish</a>
# </td>
# <td>485
# </td>
# <td><a href="/wiki/Indo-European_languages" title="Indo-European languages">Indo-European</a>
# </td>
# <td><a href="/wiki/Romance_languages" title="Romance languages">Romance</a>
# </td></tr>
# ...

# %%
rows_table = tabla_idiomas.find_all('tr')

# %%
rows = []
for row in rows_table:
    rows.append(row.find_all('td'))

rows
# Out:
# [[],
#  [<td><a class="mw-redirect" href="/wiki/ISO_639:cmn" title="ISO 639:cmn">Mandarin Chinese</a><br/>(incl. <a href="/wiki/Standard_Chinese" title="Standard Chinese">Standard Chinese</a>, but excl. <a href="/wiki/Varieties_of_Chinese" title="Varieties of Chinese">other varieties</a>)
#   </td>,
#   <td>939
#   </td>,
#   <td><a href="/wiki/Sino-Tibetan_languages" title="Sino-Tibetan languages">Sino-Tibetan</a>
#   </td>,
#   <td><a href="/wiki/Sinitic_languages" title="Sinitic languages">Sinitic</a>
#   </td>],
#  [<td><a class="mw-redirect" href="/wiki/ISO_639:spa" title="ISO 639:spa">Spanish</a>
#   </td>,
#   <td>485
#   </td>,
#   <td><a href="/wiki/Indo-European_languages" title="Indo-European languages">Indo-European</a>
#   </td>,
#   <td><a href="/wiki/Romance_languages" title="Romance languages">Romance</a>
#   </td>],
#  [<td><a class="mw-redirect" href="/wiki/ISO_639:eng" title="ISO 639:eng">English</a>
#   </td>,
#   <td>380
#   </td>,
# ...

# %%
data = []

for d in data:
    data.append(d.text)

data
# Out:
# []

# %%
table_data = table_row.find('td')

table_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/edgarahmed/Desktop/ironhack/semana_4/dia_2/labs/4.2-lab_web_scraping/your-code/ejercicios martes en sucio. scrapear.ipynb Cell 82 line 1
# ----> <a href='vscode-notebook-cell:/Users/edgarahmed/Desktop/ironhack/semana_4/dia_2/labs/4.2-lab_web_scraping/your-code/ejercicios%20martes%20en%20sucio.%20scrapear.ipynb#Y154sZmlsZQ%3D%3D?line=0'>1</a> table_data = table_row.find_all('td')
#       <a href='vscode-notebook-cell:/Users/edgarahmed/Desktop/ironhack/semana_4/dia_2/labs/4.2-lab_web_scraping/your-code/ejercicios%20martes%20en%20sucio.%20scrapear.ipynb#Y154sZmlsZQ%3D%3D?line=2'>3</a> table_dataÇ
#
# AttributeError: 'list' object has no attribute 'find_all'

# %%
ejer_6 = []

for c in table_row:
    
    ejer_6.append(c.find('td').text

ejer_6
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/edgarahmed/Desktop/ironhack/semana_4/dia_2/labs/4.2-lab_web_scraping/your-code/ejercicios martes en sucio. scrapear.ipynb Cell 83 line 5
#       <a href='vscode-notebook-cell:/Users/edgarahmed/Desktop/ironhack/semana_4/dia_2/labs/4.2-lab_web_scraping/your-code/ejercicios%20martes%20en%20sucio.%20scrapear.ipynb#Y155sZmlsZQ%3D%3D?line=0'>1</a> ejer_6 = []
#       <a href='vscode-notebook-cell:/Users/edgarahmed/Desktop/ironhack/semana_4/dia_2/labs/4.2-lab_web_scraping/your-code/ejercicios%20martes%20en%20sucio.%20scrapear.ipynb#Y155sZmlsZQ%3D%3D?line=2'>3</a> for c in table_row:
# ----> <a href='vscode-notebook-cell:/Users/edgarahmed/Desktop/ironhack/semana_4/dia_2/labs/4.2-lab_web_scraping/your-code/ejercicios%20martes%20en%20sucio.%20scrapear.ipynb#Y155sZmlsZQ%3D%3D?line=4'>5</a>     ejer_6.append(c.find('td').text)
# ...

# %%
tabla_idiomas = sopa_wiki_tabla.find('tbody')

tabla_idiomas
